estrança", "carrer de pontevedra", "carrer de l'atlantida", "carrer de vinaros", "carrer de grau i torras", "carrer de guitert", "carrer de la vila joiosa", "carrer d'alcanar", "carrer del dr fine i partagas", "carrer de berenguer mallol", "carrer de soria", "carrer de l'almirall barcelo", "carrer de santa lluisa de marillac", "carrer de la proclamacio", "carrer de salamanca", "carrer del dr.gine i partagas", "carrer d'alcanar", "carrer de la vila joiosa", "carrer de guitert", "carrer de l'atlantida", "carrer del baluard", "carrer de monjo", "carrer dels magatzems", "carrer de paderes", "carrer de sant miquel", "carrer del rector bruguera", "carrer del mar", "carrer de la mediterranea", "carrer del general castaños", "carrer de les mosques", "carrer dels ocells", "carrer de la sequia", "passeig dels til-lers", "plaça de joan fiveller"]
accesibilidad = ["no", "media", "no", "no", "no (escalones)", "media (rampa)", "media (rampa)", "media (mala superficie, no peatonal)", "media (rampa)", "media", "media", "media", "media", "no", "media", "media (superficie)", "no", "no", "no", "media", "no", "media", "no (escalones)", "media", "no (escalones)", "no", "media", "media (multitud)", "media (multitud)", "media (multitud)", "no", "no", "media (rampa)", "media", "no", "no (carril bici solo)", "no (superficie)", "no (rampa, superficie)", "media", "media (multitud)", "media", "media", "media", "media (multitud)", "media (multitud)", "no", "media", "media", "no", "no", "no", "media (superficie)", "media (superficie)", "media (multitud)", "media", "media (obras)", "media (obras)", "media (obras)", "media (multitud)", "media (multitud)", "media (multitud)", "media (multitud)", "no", "no", "media", "media", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "no", "media", "no", "no", "media", "media (superficie)", "media (superficie)"]

# %%
# si no se especifica el 'no' o el "media" accesible significa calle estrecha
# estoy ignorando las obras

# %%
df = pd.DataFrame({"latitud": latitud, "longitud": longitud, "calle":calle, "accesibilidad": accesibilidad}, index=[list(range(0, len(calle)))])
df
# Out:
#        latitud  longitud                   calle       accesibilidad
# 0    41.370812  2.173884         ctra de miramar                  no
# 1    41.370144  2.173775         ctra de miramar               media
# 2    41.369954  2.173772         ctra de miramar                  no
# 3    41.369401  2.173626         ctra de miramar                  no
# 4    41.371803  2.169597     passeig de montjuic      no (escalones)
# ..         ...       ...                     ...                 ...
# 114  41.384944  2.182513   carrer de les mosques                  no
# 115  41.389167  2.179886      carrer dels ocells                  no
# 116  41.388750  2.179563     carrer de la sequia               media
# 117  41.385970  2.186274   passeig dels til-lers  media (superficie)
# 118  41.386999  2.188583  plaça de joan fiveller  media (superficie)
#
# [119 rows x 4 columns]

# %% [markdown]
# ### Además un dataframe mostrando las condiciones de algunas calles se encontró online

# %%
df[:-60:-1]
# Out:
#        latitud  longitud                               calle  \
# 118  41.386999  2.188583              plaça de joan fiveller
# 117  41.385970  2.186274               passeig dels til-lers
# 116  41.388750  2.179563                 carrer de la sequia
# 115  41.389167  2.179886                  carrer dels ocells
# 114  41.384944  2.182513               carrer de les mosques
# 113  41.383166  2.184657         carrer del general castaños
# 112  41.382007  2.188931           carrer de la mediterranea
# 111  41.380988  2.187480                      carrer del mar
# 110  41.381005  2.187640          carrer del rector bruguera
# 109  41.381033  2.187811               carrer de sant miquel
# 108  41.381080  2.187988                   carrer de paderes
# 107  41.381070  2.188173               carrer dels magatzems
# 106  41.381073  2.188369                     carrer de monjo
# 105  41.381151  2.188522                  carrer del baluard
# ...

# %%
ruta = os.path.dirname(os.getcwd()) + os.sep + "data" + os.sep

df_adicional = pd.read_csv(ruta + "inca_od_20191115.csv")
df_adicional
# Out:
#        Gis_ID  N_Gis       X_ETRS89      Y_ETRS89    Latitud     Longitud  \
# 0          53      1  428568.771272  4.578089e+06  41.351131  2.146111263
# 1          54      2  428561.478264  4.578085e+06  41.351097  2.146024521
# 2          55      3  428547.750251  4.578095e+06  41.351181  2.145859323
# 3          75      4  431202.667072  4.582812e+06  41.393901  2.177057682
# 4          76      5  431179.358049  4.582835e+06  41.394108  2.176776259
# ...       ...    ...            ...           ...        ...          ...
# 97289  103031  97290  433062.906550  4.585193e+06  41.415503     2.199044
# 97290  103032  97291  432665.128772  4.585080e+06  41.414453     2.194297
# 97291  103033  97292  432656.740000  4.585073e+06  41.414384     2.194198
# 97292  103037  97293  432275.277073  4.582382e+06  41.390117     2.189935
# 97293  103039  97294  434625.156550  4.584508e+06  41.409465      2.21781
#
#              Incidència        Alta Situació  \
# ...

# %% [markdown]
# ### El dataframe se limpia y solo la información relevante para este proyecto es guardada

# %%
df_adicional.columns
# Out:
# Index(['Gis_ID', 'N_Gis', 'X_ETRS89', 'Y_ETRS89', 'Latitud', 'Longitud',
#        'Incidència', 'Alta', 'Situació', 'Tipus_de_tram_carrer', 'Codi_Graf',
#        'ID_element_inventari', 'Codi_Barri', 'Nom_Barri', 'Codi_Districte',
#        'Nom_Districte', 'Carrer', 'Número_Postal', 'Ubicació', 'Accesibilitat',
#        'Tipus', 'Quantitat', 'Mesura', 'Amplada_lliure_pas_central',
#        'Amplada_lliure_pas_façana', 'Adossat_a_façana_<0.50m', 'Llargada',
#        'Amplada', 'Amplada_Gual', 'Amplada_Pas_Vianants', 'Tipus_pas_vianants',
#        'Alçada', 'Amidament', 'Mesura_mínima', 'Pendent_Longitudinal',
#        'Pendent_Transversal', 'Pendent', 'Graó_Desnivell', 'Tipus_Direccional',
#        'Tipus_Botons', 'Falta_Direccional', 'Falta Botons', 'Detall_Altres',
#        'Profunditat', 'Cas_No_Compleix_Mesura_Longitudinal',
#        'Cas_No_Compleix_Mesura_Transversal', 'Senyalització_Horitzontal',
#        'Senyalització_Vertical', 'Reserva_Accessible'],
#       dtype='object')

# %%
df_adicional = df_adicional[["Latitud", "Longitud", "Carrer", "Incidència"]]
df_adicional
# Out:
#          Latitud     Longitud                Carrer        Incidència
# 0      41.351131  2.146111263         MOTORS C DELS       CanviNivell
# 1      41.351097  2.146024521         MOTORS C DELS             Guals
# 2      41.351181  2.145859323         MOTORS C DELS     AmpladaIlleta
# 3      41.393901  2.177057682       SANT JOAN PG DE          Paviment
# 4      41.394108  2.176776259          TETUAN PL DE          Paviment
# ...          ...          ...                   ...               ...
# 97289  41.415503     2.199044  EDUARD TORROJA PL D'  PlacesReservades
# 97290  41.414453     2.194297     GUIPUSCOA RBLA DE  PlacesReservades
# 97291  41.414384     2.194198     GUIPUSCOA RBLA DE  PlacesReservades
# 97292  41.390117     2.189935      RAMON TURRO C DE  PlacesReservades
# 97293  41.409465      2.21781         TAULAT PG DEL  PlacesReservades
#
# [97294 rows x 4 columns]

# %% [markdown]
# ### Las columnas son renombradas para luego juntar los dos dataframes y el tipo de incidencias son estudiadas para asegurar que consideramos las mismas y solo las calles relevantes son guardadas.

# %%
df_adicional.rename(columns={"Latitud": "latitud", "Longitud": "longitud", "Carrer": "calle", "Incidència": "accesibilidad"}, inplace=True)
df_adicional["accesibilidad"]
# Out:
# 0             CanviNivell
# 1                   Guals
# 2           AmpladaIlleta
# 3                Paviment
# 4                Paviment
#                ...
# 97289    PlacesReservades
# 97290    PlacesReservades
# 97291    PlacesReservades
# 97292    PlacesReservades
# 97293    PlacesReservades
# Name: accesibilidad, Length: 97294, dtype: object

# %% [markdown]
# ### Desafortunadamente después de verificar varios puntos en este dataframe, los problemas de accesibilidad o son erróneos o a han sido solucionados por lo que no se consdiera

# %% [markdown]
# ### Guardamos el dataframe como json

# %%
df.to_json(os.path.dirname(os.getcwd()) + os.sep + "reports" + os.sep + "obstaculos.json")

# %% [markdown]
# ### El dataframe se sube a MongoDB para que otras disciplinas tengan acceso a él

# %%
with open(os.path.dirname(os.getcwd()) + os.sep + "reports" + os.sep + "obstaculos.json", "r+") as outfile:
    obstaculos = json.load(outfile)

# %%
with open("passwords.json", "r+") as outfile:
    json_readed = json.load(outfile)
 
clave = str(json_readed["clave_sonia"])

# %%
# Connexión a MongoDB
client = MongoClient(clave)
db = client["turismo_accesible"]
collection = db["obstaculos"]


# Insertar colección
collection.insert_one(obstaculos)

# %% [markdown]
# ### Calles solo accesibles para mostrar rutas

# %%
# RUTA 1: ARCO DE TRIUNFO - PLAYA BARCELONETA

# coordenada inicial = 41.391865540769146, 2.180616749175644
# coordenada final = 41.37838500386411, 2.192477100340261

latitud = [41.391865540769146, 41.3916097164967, 41.39134832978139, 41.39057471404058, 41.39031667342777, 41.38992268553349, 41.389672383100965, 41.38891419534939, 41.38886260046384, 41.38665607698742, 41.3844336328676, 41.38322082446815, 41.38305347830762, 41.38225980279711, 41.38188537356128, 41.37799734300935, 41.37892556634381, 41.37838500386411]
longitud = [2.180616749175644, 2.1805926564187645, 2.1802775972880757, 2.1812561116761664, 2.180880756607018, 2.1813970246997743, 2.1813350924934634, 2.181486233620534, 2.1813990140274355, 2.182144823428295, 2.1849172490104483, 2.183921890003952, 2.1838877018010123, 2.185644792678837, 2.186618832828151, 2.1881997098915322, 2.1921647561779274, 2.192477100340261]
calle = ["arc de triomf", "av de vilanova", "parque", "parque", "passeig de lluis companys", "passeig de lluis companys", "carrer del comerç", "carrer del comerç", "carrer del comerç", "carrer del comerç", "av del marques de l'argentera", "av del marques de l'argentera", "pla de palau", "pla de palau", "paseo juan de borbon", "paseo juan de borbon", "pepe rubianes", "playa de la Barceloneta"]

# %%
df_ruta_1 = pd.DataFrame({"latitud": latitud, "longitud": longitud, "calle":calle}, index=[list(range(0, len(calle)))])
df_ruta_1
# Out:
#       latitud  longitud                          calle
# 0   41.391866  2.180617                  arc de triomf
# 1   41.391610  2.180593                 av de vilanova
# 2   41.391348  2.180278                         parque
# 3   41.390575  2.181256                         parque
# 4   41.390317  2.180881      passeig de lluis companys
# 5   41.389923  2.181397      passeig de lluis companys
# 6   41.389672  2.181335              carrer del comerç
# 7   41.388914  2.181486              carrer del comerç
# 8   41.388863  2.181399              carrer del comerç
# 9   41.386656  2.182145              carrer del comerç
# 10  41.384434  2.184917  av del marques de l'argentera
# 11  41.383221  2.183922  av del marques de l'argentera
# 12  41.383053  2.183888                   pla de palau
# 13  41.382260  2.185645                   pla de palau
# 14  41.381885  2.186619           paseo juan de borbon
# 15  41.377997  2.188200           paseo juan de borbon
# ...

# %%
df_ruta_1.to_json(os.path.dirname(os.getcwd()) + os.sep + "reports" + os.sep + "rutas.json")

# %%
with open(os.path.dirname(os.getcwd()) + os.sep + "reports" + os.sep + "rutas.json", "r+") as outfile:
    rutas = json.load(outfile)

# %%
# Connexión a MongoDB
client = MongoClient(clave)
db = client["turismo_accesible"]
collection = db["rutas"]


# Insertar colección
collection.insert_one(rutas)

# %%
### las siguientes rutas aun no se han añadido a mongo porque a lo mejor no se muestran

# %%
# RUTA 2: Basílica de la Sagrada Família - Plaça de Catalunya

# coordenada inicial = 41.40303886077033, 2.1739279156389975
# coordenada final = 41.38771450296937, 2.169517914558764

latitud = [41.40303886077033, 41.40180348508749, 41.39759988810457, 41.393030894405584, 41.389490402238096, 41.387906363974516, 41.38771450296937]
longitud = [2.1739279156389975, 2.175436975827992, 2.16982200073545, 2.163958129711758, 2.1685198970896855, 2.169990029333473, 2.169517914558764]
calle = ['Carrer de Sardenya', 'Calle de Valencia', 'Calle de Valencia', 'Paseo de Gracia', 'Paseo de Gracia', 'Paseo de Gracia', 'Plaza de Cataluña']

# %%
df_ruta_2 = pd.DataFrame({"latitud": latitud, "longitud": longitud, "calle":calle}, index=[list(range(0, len(calle)))])
df_ruta_2
# Out:
#      latitud  longitud               calle
# 0  41.403039  2.173928  Carrer de Sardenya
# 1  41.401803  2.175437   Calle de Valencia
# 2  41.397600  2.169822   Calle de Valencia
# 3  41.393031  2.163958     Paseo de Gracia
# 4  41.389490  2.168520     Paseo de Gracia
# 5  41.387906  2.169990     Paseo de Gracia
# 6  41.387715  2.169518   Plaza de Cataluña

# %%
# RUTA 3: plaza cataluña - mirador la rambla del mar

# coordenada inicial = 41.387010,  2.169991
# coordenada final = 41.375121, 2.180825

# %%
df_ruta_3 = pd.read_csv(os.path.dirname(os.getcwd()) + os.sep + "data" + os.sep + "ruta3.csv")

columnas = ["latitud", "longitud", "calle"]

df_ruta_3 = df_ruta_3.reindex(columns=columnas)
df_ruta_3
# Out:
#       latitud  longitud                       calle
# 0   41.387010  2.169991              plaza cataluña
# 1   41.385095  2.170506          rambla de canalets
# 2   41.382078  2.172098      mercado de la boqueria
# 3   41.381362  2.173168                   la rambla
# 4   41.380232  2.173267       gran teatro del liceo
# 5   41.378642  2.175567            plaza del teatro
# 6   41.376251  2.177627                   la rambla
# 7   41.376019  2.178203                       colon
# 8   41.375737  2.178176                    el raval
# 9   41.375531  2.178544                    el raval
# 10  41.375400  2.178925       moll de les drassanes
# 11  41.375874  2.179340           la rambla del mar
# 12  41.375520  2.180075           la rambla del mar
# 13  41.375121  2.180825   mirador la rambla del mar
