# %%
import pandas as pd
import numpy as np 
import json

# %%
d = {'Actividad': ['Playa de la Barceloneta', 'Playa de la Nueva Icaria', 'Playa del Fòrum'], 'Latitud': [41.378721571494076, 41.39047661746785, 41.4170769270860], 'Longitud': [2.1922780975424034, 2.2023382638653084, 2.231379795940143] , 'Descripción':['Aparcamientos reservados. Itinerario adaptado hasta la playa seca. Itinerario adaptado hasta el agua de la playa, Plataforma de pasarelas para la estancia de los usuarios y usuarias. Duchas, vestuarios y baños adaptados. Taquillas adaptadas. Grúa elevadora, dos sillas anfibias, chaleco salvavidas, flotadores y parasoles.','Aparcamientos reservados en el paseo marítimo. Itinerario adaptado hasta la playa seca. Itinerario adaptado hasta el agua de la playa. Plataforma de pasarelas para la estancia de los usuarios y usuarias. Duchas, vestuarios y baños adaptados. Grúa elevadora, dos sillas anfibias, chaleco salvavidas, flotadores y para-soles. Pérgola para proteger del sol a la zona de espera de la playa.', 'Plazas de parking reservadas. Itinerario adaptado hasta la playa seca. Itinerario adaptado hasta el agua de la playa. Servicio de hamacas gratuito para tener más comodidad. Duchas, vestuarios y baños adaptados. Zona de sombra habilitada. Silla hidráulica elevadora para acceder al agua.']}

# %%
actividades = pd.DataFrame(data= d)
actividades
# Out:
#                   Actividad    Latitud  Longitud  \
# 0   Playa de la Barceloneta  41.378722  2.192278
# 1  Playa de la Nueva Icaria  41.390477  2.202338
# 2           Playa del Fòrum  41.417077  2.231380
#
#                                          Descripción
# 0  Aparcamientos reservados. Itinerario adaptado ...
# 1  Aparcamientos reservados en el paseo marítimo....
# 2  Plazas de parking reservadas. Itinerario adapt...

# %%
act = pd.read_csv('activities.csv')
act
# Out:
#        register_id                                               name  \
# 0      ﻿1299140408              Exposició permanent del Museu Picasso
# 1      ﻿1312163221  Visita Guiada a la Casa de Convalescència de l...
# 2     ﻿92195132407                          Port Olímpic de Barcelona
# 3     ﻿92195132407                          Port Olímpic de Barcelona
# 4     ﻿96250132330  L'art de visitar un jardí "El Parc del Laberin...
# ...            ...                                                ...
# 2595  ﻿99400663559                        Concert "Funzo & Baby Loud"
# 2596  ﻿99400663561                                  Concert "Eskorzo"
# 2597  ﻿99400666209  Casal esportiu 'Educació primària multiesporti...
# 2598  ﻿99400666218  Casal d'estiu per a infants i adolescents de 3...
# 2599  ﻿99400664468                      Concert "Ebano & Luis Amoeba"
#
#       institution_id institution_name                           created  \
# ...

# %%
act.isnull().sum()
# Out:
# register_id                         0
# name                                0
# institution_id                   2591
# institution_name                 2591
# created                             0
# modified                          443
# addresses_roadtype_id            2600
# addresses_roadtype_name          2600
# addresses_road_id                  89
# addresses_road_name                84
# addresses_start_street_number      97
# addresses_end_street_number      2378
# addresses_neighborhood_id          88
# addresses_neighborhood_name        92
# addresses_district_id              83
# addresses_district_name            84
# addresses_zip_code                 85
# addresses_town                      1
# addresses_main_address              0
# addresses_type                   2600
# values_id                        1480
# values_attribute_id              1480
# values_category                  1480
# values_attribute_name            1480
# values_value                     1480
# ...

# %%
act = act.dropna(how='all')

# %%
act. columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_x', 'geo_epgs_4326_y'],
#       dtype='object')

# %%
act = act[['name','geo_epgs_25831_x', 'geo_epgs_25831_y','geo_epgs_4326_x', 'geo_epgs_4326_y']]
act
# Out:
#                                                    name  geo_epgs_25831_x  \
# 0                 Exposició permanent del Museu Picasso               NaN
# 1     Visita Guiada a la Casa de Convalescència de l...     430513.775506
# 2                             Port Olímpic de Barcelona     433054.284674
# 3                             Port Olímpic de Barcelona     433054.284674
# 4     L'art de visitar un jardí "El Parc del Laberin...     428784.911985
# ...                                                 ...               ...
# 2595                        Concert "Funzo & Baby Loud"     430550.699311
# 2596                                  Concert "Eskorzo"     430550.569881
# 2597  Casal esportiu 'Educació primària multiesporti...     432763.890037
# 2598  Casal d'estiu per a infants i adolescents de 3...     432458.983465
# 2599                      Concert "Ebano & Luis Amoeba"     432380.384999
#
#       geo_epgs_25831_y  geo_epgs_4326_x  geo_epgs_4326_y
# ...

# %%
act = act.dropna(how='any')

# %%
act.reset_index(drop=True, inplace=True)

# %%
act
# Out:
#                                                    name  geo_epgs_25831_x  \
# 0     Visita Guiada a la Casa de Convalescència de l...     430513.775506
# 1                             Port Olímpic de Barcelona     433054.284674
# 2                             Port Olímpic de Barcelona     433054.284674
# 3     L'art de visitar un jardí "El Parc del Laberin...     428784.911985
# 4             Visita als jardins del Palau de Pedralbes     426293.530405
# ...                                                 ...               ...
# 2528                        Concert "Funzo & Baby Loud"     430550.699311
# 2529                                  Concert "Eskorzo"     430550.569881
# 2530  Casal esportiu 'Educació primària multiesporti...     432763.890037
# 2531  Casal d'estiu per a infants i adolescents de 3...     432458.983465
# 2532                      Concert "Ebano & Luis Amoeba"     432380.384999
#
#       geo_epgs_25831_y  geo_epgs_4326_x  geo_epgs_4326_y
# ...

# %%
 act.to_excel('act.xlsx')

# %%
act['name'].value_counts()
# Out:
# Bibliocasal (dimecres TARDA).                                                                     41
# Centre Esportiu Municipal Estació del Nord                                                        13
# Centre Esportiu Municipal Olímpics Vall Hebron                                                    12
# Centre Esportiu Municipal l'Espanya Industrial                                                    12
# Centre Esportiu Municipal  Colom                                                                  10
#                                                                                                   ..
# Concert "Carles Cases Strings Band"                                                                1
# Casal La Sedeta                                                                                    1
# Festival de Música Sudcoreana "Munhwa"                                                             1
# ...

# %%
oci = pd.read_csv('ocio.csv')
oci
# Out:
#       register_id                                               name  \
# 0    ﻿92086010252                                             Teatre
# 1    ﻿99400165038                                  Teatre - Auditori
# 2     ﻿1331135946                              Sala Fabià Puigserver
# 3    ﻿92168176499  Sala Beckett - Obrador Internacional de Dramat...
# 4    ﻿92086013951                                             Teatre
# ..            ...                                                ...
# 194  ﻿92086015534                                         Auditòrium
# 195  ﻿99400664939                                       Teatre Apolo
# 196  ﻿99400187001                                    Cinema Dididado
# 197  ﻿99400654904                           Sala Clan Destino Mental
# 198  ﻿92086000123                                        Teatre Grec
#
#      institution_id                                   institution_name  \
# ...

# %%
oci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   register_id                    199 non-null    object
#  1   name                           199 non-null    object
#  2   institution_id                 106 non-null    float64
#  3   institution_name               106 non-null    object
#  4   created                        199 non-null    object
#  5   modified                       188 non-null    object
#  6   addresses_roadtype_id          0 non-null      float64
#  7   addresses_roadtype_name        0 non-null      float64
#  8   addresses_road_id              199 non-null    int64
#  9   addresses_road_name            199 non-null    object
#  10  addresses_start_street_number  199 non-null    int64
#  11  addresses_end_street_number    2 non-null      float64
# ...

# %%
oci.columns
# Out:
# Index(['register_id', 'name', 'institution_id', 'institution_name', 'created',
#        'modified', 'addresses_roadtype_id', 'addresses_roadtype_name',
#        'addresses_road_id', 'addresses_road_name',
#        'addresses_start_street_number', 'addresses_end_street_number',
#        'addresses_neighborhood_id', 'addresses_neighborhood_name',
#        'addresses_district_id', 'addresses_district_name',
#        'addresses_zip_code', 'addresses_town', 'addresses_main_address',
#        'addresses_type', 'values_id', 'values_attribute_id', 'values_category',
#        'values_attribute_name', 'values_value', 'values_outstanding',
#        'values_description', 'secondary_filters_id', 'secondary_filters_name',
#        'secondary_filters_fullpath', 'secondary_filters_tree',
#        'secondary_filters_asia_id', 'geo_epgs_25831_x', 'geo_epgs_25831_y',
#        'geo_epgs_4326_x', 'geo_epgs_4326_y'],
#       dtype='object')

# %%
oci = oci[['name','geo_epgs_25831_x', 'geo_epgs_25831_y','geo_epgs_4326_x', 'geo_epgs_4326_y']]
oci
# Out:
#                                                   name  geo_epgs_25831_x  \
# 0                                               Teatre     431530.158651
# 1                                    Teatre - Auditori     429344.021386
# 2                                Sala Fabià Puigserver     429523.353388
# 3    Sala Beckett - Obrador Internacional de Dramat...     433085.991990
# 4                                               Teatre     432363.536820
# ..                                                 ...               ...
# 194                                         Auditòrium     426025.303052
# 195                                       Teatre Apolo     430620.233184
# 196                                    Cinema Dididado     426447.038058
# 197                           Sala Clan Destino Mental     427681.304317
# 198                                        Teatre Grec     429622.026485
#
#      geo_epgs_25831_y  geo_epgs_4326_x  geo_epgs_4326_y
# ...

# %%
oci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              199 non-null    object
#  1   geo_epgs_25831_x  199 non-null    float64
#  2   geo_epgs_25831_y  199 non-null    float64
#  3   geo_epgs_4326_x   199 non-null    float64
#  4   geo_epgs_4326_y   199 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.9+ KB

# %%
oci['name'].value_counts()
# Out:
# Teatre                                      44
# Auditori                                     8
# Sala de Cinema                               5
# Auditòrium                                   4
# Sala Barcelona 92 - Sala Sant Jordi Club     3
#                                             ..
# Teatre Goya                                  1
# Teatre - Auditori                            1
# Aribau Multicines                            1
# Comedianet                                   1
# La Puntual. Putxinel.lis de Barcelona        1
# Name: name, Length: 129, dtype: int64

# %%
oci.to_excel('oci.xlsx')

# %%
monumentos = pd.read_json('http://www.bcn.cat/tercerlloc/files/opendatabcn_pits.json')
monumentos.columns
# Out:
# Index(['register_id', 'prefix', 'suffix', 'name', 'created', 'modified',
#        'status', 'status_name', 'core_type', 'core_type_name', 'body',
#        'tickets_data', 'addresses', 'entity_types_data',
#        'attribute_categories', 'values', 'from_relationships',
#        'to_relationships', 'classifications_data', 'secondary_filters_data',
#        'timetable', 'image_data', 'gallery_data', 'warnings', 'geo_epgs_25831',
#        'geo_epgs_23031', 'geo_epgs_4326', 'is_section_of_data',
#        'sections_data', 'start_date', 'end_date', 'estimated_dates',
#        'languages_data', 'type', 'type_name', 'period', 'period_name',
#        'event_status_name', 'event_status', 'ical'],
#       dtype='object')

# %%
monumentos = monumentos[['name', 'geo_epgs_4326']]
monumentos
# Out:
#                                                   name  \
# 0    Escultura David i Goliat Homenatge a les Briga...
# 1             Associació d'Amics del Passeig de Gràcia
# 2                                    Parc de Cervantes
# 3                    Casa Faiol - Casa de la Papallona
# 4                       Escola Mossèn Jacint Verdaguer
# ..                                                 ...
# 843                                       Ca n'Andalet
# 844                              Parc de la Ciutadella
# 845                          Tramvia Blau Tibidabo-TMB
# 846  Temple Expiatori de la Sagrada Família - Basílica
# 847                 Centre Cívic El Coll - La Bruguera
#
#                                          geo_epgs_4326
# 0      {'x': 41.4248731521239, 'y': 2.157703561885268}
# 1      {'x': 41.3914081134819, 'y': 2.165360667698721}
# 2     {'x': 41.38456852873158, 'y': 2.109439404649357}
# 3    {'x': 41.376636975984155, 'y': 2.150298953457356}
# ...

# %%
monumentos1 = pd.concat([monumentos.drop(['geo_epgs_4326'], axis=1), monumentos['geo_epgs_4326'].apply(pd.Series)], axis=1)

# %%
monumentos1.to_excel('monumentos1.xlsx')

# %%
hello = pd.read_csv('ocio_actividades_code.csv', sep =';')
hello
# Out:
#                                Actividad      Latitud     Longitud Categoria  \
# 0                Playa de la Barceloneta  41,37872157  2,192278098     Playa
# 1               Playa de la Nueva Icaria  41,39047662  2,202338264     Playa
# 2                        Playa del Forum  41,41707693  2,231379796     Playa
# 3                  Playa de San Sebastia  41,37036929  2,189082506     Playa
# 4                      Playa de Bogatell  41,39710273  2,211043562     Playa
# ..                                   ...          ...          ...       ...
# 69       Basilica de Santa Maria del Mar  41,38378222   2,18222495  Iglesias
# 70      Iglesia San Pedro de las Puellas  41,38922892  2,179243019  Iglesias
# 71           Monasterio San Pau del Camp  41,37802611  2,170832149  Iglesias
# 72               Iglesia San Felipe Neri  41,38441915  2,176604072  Iglesias
# 73  Basilica de los santos Just y Pastor  41,39398015  2,175853249  Iglesias
#
# ...

# %%
hello.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Actividad    74 non-null     object
#  1   Latitud      74 non-null     object
#  2   Longitud     74 non-null     object
#  3   Categoria    74 non-null     object
#  4   Web          73 non-null     object
#  5   Descripcion  74 non-null     object
# dtypes: object(6)
# memory usage: 3.6+ KB

# %%
hello['Latitud']=hello['Latitud'].apply(lambda x: x.replace(',',".")).astype('float')

# %%
hello['Longitud']=hello['Longitud'].apply(lambda x: x.replace(',',".")).astype('float')

# %%
hello
# Out:
#                                Actividad    Latitud  Longitud Categoria  \
# 0                Playa de la Barceloneta  41.378722  2.192278     Playa
# 1               Playa de la Nueva Icaria  41.390477  2.202338     Playa
# 2                        Playa del Forum  41.417077  2.231380     Playa
# 3                  Playa de San Sebastia  41.370369  2.189083     Playa
# 4                      Playa de Bogatell  41.397103  2.211044     Playa
# ..                                   ...        ...       ...       ...
# 69       Basilica de Santa Maria del Mar  41.383782  2.182225  Iglesias
# 70      Iglesia San Pedro de las Puellas  41.389229  2.179243  Iglesias
# 71           Monasterio San Pau del Camp  41.378026  2.170832  Iglesias
# 72               Iglesia San Felipe Neri  41.384419  2.176604  Iglesias
# 73  Basilica de los santos Just y Pastor  41.393980  2.175853  Iglesias
#
#                                                   Web  \
# ...

# %%
hello.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Actividad    74 non-null     object
#  1   Latitud      74 non-null     float64
#  2   Longitud     74 non-null     float64
#  3   Categoria    74 non-null     object
#  4   Web          73 non-null     object
#  5   Descripcion  74 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 3.6+ KB

# %%
hello.to_json('actividades_code.json')

# %%
from pymongo import MongoClient
# Load csv dataset
#data = pd.read_json("actividades.json")
with open("actividades_code.json") as actividades:
    actividades_dict = json.load(actividades)
# Connect to MongoDB
client =  MongoClient('enlace')
db = client["turismo_accesible"]
collection = db["actividades"]
#data.to_dict("actividades")
collection.insert_one(actividades_dict)
# Insert collection
#collection.insert_many("actividades.json")

# %%
actividades_dict
# Out:
# {'actividad': {'0': 'Playa de la Barceloneta',
#   '1': 'Playa de la Nueva Icaria',
#   '2': 'Playa del Forum',
#   '3': 'Playa de San Sebastia',
#   '4': 'Playa de Bogatell',
#   '5': 'Playa de la Mar Bella',
#   '6': 'Playa de Llevant',
#   '7': 'Playa de Somorrostro',
#   '8': 'Puerto Olimpico de Barcelona',
#   '9': 'La Sagrada Familia',
#   '10': 'La Pedrera ',
#   '11': 'Casa Batllo ',
#   '12': 'La Rambla',
#   '13': 'Mercado de la Boqueria',
#   '14': 'Parque Guell',
#   '15': 'Museo Picasso',
#   '16': 'Plaza CataluÃ±a',
#   '17': 'Catedral de Barcelona',
#   '18': 'Camp Nou',
#   '19': 'Palacio Musica Catalana',
#   '20': 'Gran Teatro Liceo',
#   '21': 'Mirador de Colon',
#   '22': 'Arco del Triunfo de Barcelona',
#   '23': 'Palacio Guell',
#   '24': 'La Monumental',
#   '25': 'Plaza de Sant Jaume',
#   '26': 'Plaza del Rey',
#   '27': 'Basilica de Santa Maria del Pi',
#   '28': 'Parlamento de CataluÃ±a',
#   '29': 'La Estrella herida',
#   '30': 'Gato. Fernando Botero',
# ...
